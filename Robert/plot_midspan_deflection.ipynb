# %%
from matplotlib import pyplot as plt
import netCDF4
data='output.nc'
nc = netCDF4.Dataset(data)

# %%
plt.figure(figsize=(20,10))
plt.plot(nc["time"][:], nc["u"][:,753])
plt.title("Displacement of midspan")
plt.xlabel("time [s]")
plt.ylabel("displacement [m]")
plt.savefig("disp_midspan.png")
